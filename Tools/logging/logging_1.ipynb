# %%
import logging

# %% [markdown]
# ## debugging levels
# ![image.png](attachment:image.png)

# %% [markdown]
# ## writing in console

# %%
logging.basicConfig(level=logging.DEBUG,
                    format="%(asctime)s-%(name)s-%(levelname)s-%(message)s",
                    datefmt="%Y-%m-%d",
                    force=True)  # code can be run without format as well
logging.debug("this is a debug message")
logging.warning("this is a warning message")
logging.error("this is an error message")
logging.critical("this is a critical message")

# %% [markdown]
# ## writting in file

# %%
logging.basicConfig(
                    filename="log.txt",
                    filemode="w",
                    level=logging.DEBUG,
                    format="%(asctime)s-%(name)s-%(levelname)s-%(message)s",
                    datefmt="%Y-%m-%d",
                    force=True)  # code can be run without format as well
logging.debug("this is a debug message")
logging.warning("this is a warning message")
logging.error("this is an error message")
logging.critical("this is a critical message")

# %% [markdown]
# 1)  the logging can be imported directly in other file and can be used for logging
# like this
# ```python
# #~test.py
#
# from logging_1 import logging
#
# def add(a,b):
#     logging.debug("addition is taking place")
#     return a +b
# ```
